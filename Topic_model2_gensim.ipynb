# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim
import string
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

morph = MorphAnalyzer()

# %% [markdown]
# ## Данные

# %%
stops = set(stopwords.words('russian'))
stops |= set(stopwords.words('english'))

# %%
#stops = set(stopwords.words('russian')) | {'gt',}

def remove_tags(text):
    text = re.sub('&gt;', '', text)
    text = re.sub('&lt;', '', text)
    text = re.sub('\\t', '', text)
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return norm_words

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %%
morph.parse('jc')[0].tag
# Out:
# OpencorporaTag('LATN')

# %% [markdown]
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор); -- +
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы); --+
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова); -- +
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [tokenize(remove_tags(text.lower())) for text in texts]
# Out:
# CPU times: user 3.23 s, sys: 465 ms, total: 3.69 s
# Wall time: 3.78 s

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [normalize(tokenize(text.lower())) for text in texts]

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)
# Out:
# CPU times: user 13.1 s, sys: 747 ms, total: 13.8 s
# Wall time: 14.1 s

# %%
# для нграммов
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]

# %% [markdown]
# #### 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);

# %%
all_t = Counter([])
for lst in texts:
    all_t += Counter(lst)

# %%
all_n = Counter([])
for lst in ngrammed_texts:
    all_n += Counter(lst)

# %%
stops_t = {i[0] for i in all_t.most_common(50)}
stops_n = {i[0] for i in all_n.most_common(50)}
least_n = {i[0] for i in all_n.most_common()[:-100-1:-1]}
least_t = {i[0] for i in all_n.most_common()[:-100-1:-1]}

# %%
stops = stops | new_stops_t | new_stops_n | least_n | least_t

# %%
len(stops)
# Out:
# 534

# %%
# %%time
texts_new_stops = open('habr_texts.txt').read().splitlines()
texts_new_stops = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts_new_stops], 30000)
ph = gensim.models.Phrases(texts_new_stops, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts_new_stops = p[texts_new_stops]
# Out:
# CPU times: user 44.2 s, sys: 1.28 s, total: 45.5 s
# Wall time: 49 s

# %%
texts = ngrammed_texts_new_stops

# %%
del texts_new_stops

# %% [markdown]
# ## 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;

# %% [markdown]
# ### Тематическое моделирование в gensim

# %% [markdown]
# Для моделей нужно сделать словарь.

# %%
dictinary = gensim.corpora.Dictionary(texts)

# %%
dictinary.filter_extremes(no_above=0.3)
dictinary.compactify()

# %%
print(dictinary)
# Out:
# Dictionary(15489 unique tokens: ['2-х', '3', 'address', 'api', 'assembly']...)

# %% [markdown]
# Преобразуем наши тексты в мешки слов.

# %%
corpus = [dictinary.doc2bow(text) for text in texts]
# если текстов много, то тут может быть генератор

# %%
# ?gensim.models.LdaMulticore

# %%
# %%time
lda = gensim.models.LdaMulticore(corpus, 100, id2word=dictinary, passes=5, workers=2, eta='auto', iterations=10) # если поддерживается многопоточность 
#lda = gensim.models.LdaModel(200, id2word=dictinary, passes=5)

# %%
def my_lda(texts, num_topics=10, passes=10, eta='auto', tf=False):
            
    dictinary = gensim.corpora.Dictionary(texts)
    dictinary.filter_extremes(no_above=0.3)
    dictinary.compactify()
    
    corpus = [dictinary.doc2bow(text) for text in texts]
    
    if tf:
        tfidf = gensim.models.TfidfModel(corpus, id2word=dictinary)
        corpus = tfidf[corpus]

    lda = gensim.models.LdaModel(corpus, id2word=dictinary, 
                                 passes=passes, num_topics=num_topics,
                                 eta=eta, random_state=42)
    #lda = gensim.models.LdaMulticore(corpus=corpus, num_topics=num_topics,
                                    # workers=workers, passes=passes,
                                   #  eta=eta, iterations=iterations,
                                   #  id2word=dictinary,
                                   #  random_state=42)
    return lda

# %%
lda = my_lda(texts)

# %% [markdown]
# Посмотрим на топики.

# %%
import pandas as pd


def words(lda):
    d = {}

    for index, line in enumerate(lda.print_topics()):
        d[index] = re.findall('"(.*?)"', line[1])
    
    return pd.DataFrame(d)

# %%
words(lda)
# Out:
#           0             1              2            3             4  \
# 0       new          мозг    температура       модуль        страна
# 1     класс          боль         машина     заказчик       событие
# 2  свойство        сигнал          режим  архитектура  безопасность
# 3      null   изображение         прибор   управление        доступ
# 4        id     изменение       скорость    платформа        защита
# 5   атрибут   происходить           звук       услуга     сотрудник
# 6  function        учёный         камера     документ      интернет
# 7  параметр       область           цена       сервис       правило
# 8      поль            её  производитель    изменение   организация
# 9       int  пространство         корпус       запрос    специалист
#
#            5          6          7         8            9
# 0     массив   страница     услуга     игрок            c
# 1      пакет    браузер     доступ  какой-то     алгоритм
# 2       тест  сообщение     трафик   продукт         цикл
# 3     запрос  мобильный     сервис      день        слово
# 4      режим        бот      домен    что-то       ошибка
# 5     память   название       база       мир       строка
# 6       ядро    контент      канал    понять         блок
# 7       узел      поиск   протокол      опыт   переменный
# 8  настройка   добавить   передача    деньга  изображение
# 9  контейнер     пароль  настройка      цель        точка

# %% [markdown]
# темы неплохие, но посмотрим что изменится, если изменить параметры

# %% [markdown]
# Вообще темы получились неплохие, например, 14 - про обучение, 16,9,5,1 - связанные с программированием, 17 - про убер

# %% [markdown]
# 50 топиков, 10 passes

# %%
lda = my_lda(texts, num_topics=50, passes=10, eta='auto')
words(lda)
# Out:
#               0             1           2             3            4   \
# 0      microsoft        услуга   компонент        модуль  температура
# 1  visual_studio        сервис      шаблон  спецификация     скорость
# 2            net      документ     angular       браузер       печать
# 3          azure    дата-центр       react      загрузка      головка
# 4       net_core         рынок         div     загрузчик         вода
# 5         visual  оборудование    страница         квт*ч       датчик
# 6         opencv   предприятие  компонента     изменение     материал
# 7        xamarin        страна     div_div  поддерживать      диаметр
# 8            mac         китай    template         карта        тепло
# 9     sql_server    управление         тег           api      принтер
#
#               5             6            7              8         9   \
# 0         google      заказчик      ребёнок    архитектура  свойство
# 1     российский        что-то      студент         логика   атрибут
# 2          закон       продукт     младенец          поток      null
# 3       документ      какой-то     участник      presenter    object
# 4     корпорация  тестирование     родитель           uber     класс
# 5   законопроект      понимать  контрольный      состояние    задать
# 6             рф      ожидание      отметка       облачный       new
# 7            суд        думать        набор  представление    public
# 8  представитель       правило      предмет      платформа      поль
# 9  идентификация        понять       группа  бизнес-логика   summary
#
#               10          11           12            13                  14  \
# 0           боль       робот        текст          мозг                тест
# 1       firebase         дом        слово       область      вычислительный
# 2      изменение      сигнал      перевод        сигнал         виртуальный
# 3  сопротивление  управление     название          лицо  производительность
# 4    определение    смартфон   английский   изображение           сообщение
# 5            мир       связь       символ            её            задержка
# 6     социальный      гаджет       дизайн          свет            операция
# 7          ткань        звук       кнопка        учёный                ядро
# 8    происходить        база  комментарий   происходить                  ос
# 9          аудио     телефон  локализация  исследование            алгоритм
#
#            15          16                    17           18           19
# 0  переменный       товар                  узел      питание     function
# 1         int     покупка            infiniband   контроллер        стиль
# 2      дефект      скидка               кластер  температура  рефакторинг
# 3           c     магазин              mellanox       корпус   javascript
# 4      дерево        цена          google_cloud        плата     контекст
# 5    проверка  покупатель          включительно   напряжение        const
# 6      ошибка       заказ              неохотно      станция         html
# 7    оператор     продажа  специально_обученный          ток       логика
# 8           x        день                    56     резистор     документ
# 9   выражение      amazon                   j_j    светодиод    структура

# %% [markdown]
# 50 топиков, 5 passes

# %%
lda = my_lda(texts, num_topics=50, passes=5, eta='auto')
words(lda)
# Out:
#              0            1              2              3              4   \
# 0       продукт    мобильный         клетка           цена    архитектура
# 1          цель      android         страна           диск         логика
# 2     сотрудник  электроника         учёный              4      presenter
# 3        анализ  аккумулятор       развитие        ноутбук           uber
# 4        бизнес        apple   исследование          экран          поток
# 5  исследование      батарея            мир              8      состояние
# 6      цифровой     нативный       интернет  производитель      платформа
# 7        группа     подборка            ген       смартфон  представление
# 8   технический       iphone  исследователь        сегодня  бизнес-логика
# 9       больший     смартфон          жизнь        дисплей            mvc
#
#              5           6            7              8                9   \
# 0        доступ      скрипт       услуга            new       контроллер
# 1  безопасность   настройка       сервис         result          питание
# 2        защита   контейнер     документ           case           корпус
# 3       событие      пароль   дата-центр           java            плата
# 4       правило       пакет        рынок       customer       напряжение
# 5         атака  установить       доступ              3      температура
# 6      инцидент   установка        китай      statement         резистор
# 7    уязвимость   настроить  предприятие      структура          станция
# 8   организация       папка       страна         amount        светодиод
# 9    репликация    параметр     интернет  result_result  микроконтроллер
#
#              10            11                  12           13           14  \
# 0          мозг        модуль      вычислительный     function  температура
# 1        сигнал  спецификация                тест     контекст     скорость
# 2       область       браузер         виртуальный        стиль      головка
# 3          лицо      загрузка           сообщение  рефакторинг       печать
# 4   изображение         квт*ч              печать   javascript     мощность
# 5          свет     изменение            задержка        класс       датчик
# 6            её  поддерживать  производительность        const         вода
# 7   происходить         карта            операция         html      диаметр
# 8          глаз        import                ядро       логика      площадь
# 9  пространство  представлять         современный   вычисление        тепло
#
#            15             16          17        18          19
# 0       товар         google       робот    массив       точка
# 1      скидка     российский         дом      цикл  автомобиль
# 2       заказ       документ    смартфон         c       ребро
# 3        цена          закон  управление    строка    водитель
# 4      amazon   законопроект        звук  алгоритм         3cx
# 5     магазин             рф      гаджет   таблица         рис
# 6  покупатель     корпорация      сигнал         r         луч
# 7     покупка            суд       связь         3        маяк
# 8       акция  представитель        база         n   видимость
# 9    доставка  идентификация  синтезатор     слово        тест

# %% [markdown]
# хорошие темы - 1, 6, 15, 18

# %% [markdown]
# 100 топиков, 10 passes

# %%
lda = my_lda(texts, num_topics=100, passes=10, eta='auto')
words(lda)
# Out:
#              0              1              2            3                  4   \
# 0          мозг        ansible         пароль        поезд            область
# 1        клетка         opencv      компьютер        земля           обучение
# 2       ребёнок  маршрутизатор        windows      аппарат              набор
# 3        учёный         миньон           ключ       орбита             группа
# 4      младенец       employee          домен         км/ч           алгоритм
# 5       область         мастер         доступ  космический            признак
# 6          тело           salt         скрипт      спутник  машинный_обучение
# 7  исследование    вдохновение     windows_10         марс           блокчейн
# 8       пациент            lsa  администратор       миссия        контрольный
# 9      организм           роль      настройка        полёт          нейросеть
#
#            5           6                7         8            9           10  \
# 0    кампания           c       юридически    скидка       порция      массив
# 1  объявление      ошибка          ступень     акция         nmap        цикл
# 2   заголовок      плагин  авторский_право     заказ    популяция  репликация
# 3     adwords  инструмент          научный     месяц        caché       режим
# 4      группа         php       technology      день         шелл  переменный
# 5      сервис  анализатор            smile     пакет       хищник           r
# 6     перенос   resharper       publishing     тариф     question    параметр
# 7      формат       cmake         research        30       осадок    итерация
# 8        ключ   множество          science  промокод  численность           3
# 9      символ       clion   орбита_спутник   хостинг          arc       пакет
#
#           11             12              13             14            15  \
# 0      домен            rec  проектирование       цифровой       энергия
# 1     ссылка          swift            блок       открытый     вселенная
# 2      поиск             st        прототип          набор        звезда
# 3      канал       nintendo   unsigned_char      состояние        учёный
# 4    контент             dx   кнопка_нажать          смысл            её
# 5  presenter        swift_3       интерфейс           uber        теория
# 6    скачать    super_mario            этап  рабочий_место      скорость
# 7     музыка             jr           макет     публикация       частица
# 8      релиз  подача_заявка        страница           лицо     галактика
# 9   страница            nes          дизайн         знание  существовать
#
#           16          17             18         19
# 0     прибор  библиотека      диспетчер      слайд
# 1  двигатель          js   raspberry_pi        тэг
# 2       метр          ef  синий_зелёный     values
# 3      связь     angular            iot        key
# 4       вода  фреймворка       собрание       ключ
# 5     здание  javascript           hdmi         li
# 6     машина   фреймворк       триггера     signal
# 7     сигнал       apple            usb    collate
# 8    причина      виджет         кружка  args_args
# 9   точность         кэш          покой    allowed

# %% [markdown]
# хорошие темы - 0, 2, 3, ...

# %% [markdown]
# Все темы достаточно хорошие, видимо, с увеличением числа топиков, растет качество их определения

# %% [markdown]
# 100 топиков, 5 passes

# %%
lda = my_lda(texts, num_topics=100, passes=5, eta='auto')
words(lda)
# Out:
#                 0                            1          2                3   \
# 0              бот                           ия      доход             боль
# 1         messages                       анализ      налог           камера
# 2        сообщение                 безопасность      сумма        изменение
# 3              php                      больший         ип    сопротивление
# 4         страница               характеристика     расход      определение
# 5          twitter                      высокий        ооо         ситуация
# 6               id  информационный_безопасность       счёт  видеонаблюдение
# 7            логин                  организация      рубль            видео
# 8            форма      искусственный_интеллект  налоговый      происходить
# 9  public_function                       личный     бизнес   сопротивляться
#
#                    4             5               6                7   \
# 0                 бар     std::cout  проектирование          рейтинг
# 1            скафандр             5   unsigned_char  нервный_волокно
# 2                болт             6   кнопка_нажать           uint64
# 3       проигрыватель             3        прототип            third
# 4           пластинка  включительно            блок        page_page
# 5           виниловый           inf        страница          покупка
# 6                шлем           min         хакатон        final_int
# 7  выступление_спикер             4            этап              idx
# 8                 xxi           3_4           макет           string
# 9               final       int_int       интерфейс       identifier
#
#              8               9          10                   11  \
# 0  бронирование       усилитель    шорткат           библиотека
# 1          epam          сигнал  сообщение                   ef
# 2         юрист          гаджет    android              angular
# 3        сергей            звук   действие                   js
# 4    подать_суд       помещение   добавить                apple
# 5   калькулятор  характеристика     маячок  общественный_мнение
# 6       василий          фильтр   короткий               vue.js
# 7       два-три       искажение     иконка            фреймворк
# 8         night       изменение      сутки                  кэш
# 9       договор          воздух    телефон           фреймворка
#
#               12           13        14             15             16  \
# 0    архитектура   инструмент  страница         пароль        ansible
# 1         запрос       музыка     стиль      компьютер         opencv
# 2  бизнес-логика     название  документ    подключение  маршрутизатор
# 3             id   синтезатор      html         доступ       employee
# 4           view       движок       css           ключ         миньон
# 5         логика        релиз       dom          домен           salt
# 6  представление  современный   пиксель  администратор         мастер
# 7          поток        серия    ширина      настройка            lsa
# 8     содержимый   библиотека    размер          админ    вдохновение
# 9            asc            c      main     windows_10      saltstack
#
#                    17          18                19
# 0         виртуальный   компонент         диспетчер
# 1            облачный         div      raspberry_pi
# 2               среда       react     синий_зелёный
# 3          infiniband     div_div          собрание
# 4                  ос      шаблон              hdmi
# 5      инфраструктура         тег              0x07
# 6  виртуальный_машина  компонента            кружка
# 7  производительность  визуальный          триггера
# 8       виртуализация    страница  многое_благодаря
# 9          физический     angular           pentium

# %% [markdown]
# В словах встречаются числа, попробуем их убрать.

# %%
def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {}
    for word, _ in uniq.most_common(top):
        mp = morph.parse(word)[0]
        if 'NUMB' not in mp.tag:
            norm_uniq[word] = mp.normal_form
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

# %%
texts = open('habr_texts.txt').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
texts = p[texts]

# %%
lda = my_lda(texts, num_topics=100, passes=15, eta='auto')
table1 = words(lda)

# %% [markdown]
# ## для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;

# %% [markdown]
# Хорошая тема про зрение (лезерную коррекцию зрения)

# %%
table1[1]
# Out:
# 0    операция
# 1        глаз
# 2       лазер
# 3          тз
# 4      зрение
# 5       линза
# 6        flex
# 7    роговица
# 8      хирург
# 9     пациент
# Name: 1, dtype: object

# %% [markdown]
# Хорошая тема про учебу

# %%
table1[10]
# Out:
# 0             студент
# 1                курс
# 2    программирование
# 3             ребёнок
# 4              лекция
# 5            обучение
# 6         программист
# 7     образовательный
# 8           компьютер
# 9              знание
# Name: 10, dtype: object

# %% [markdown]
# Хорошая тема про здоровье

# %%
table1[19]
# Out:
# 0        пациент
# 1           врач
# 2        лечение
# 3        болезнь
# 4    заболевание
# 5       бактерия
# 6       медицина
# 7       организм
# 8            3cx
# 9        больной
# Name: 19, dtype: object

# %% [markdown]
# #### 6) между словарем и обучением модели добавьте tfidf (gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]);
# #### 7) повторите пункт 4 на преобразованном корпусе;

# %%
lda = my_lda(texts, num_topics=50, passes=10, eta='auto', tf=True)
table = words(lda)

# %%
table
# Out:
#                        0                                              1   \
# 0               усилитель                                       вакансия
# 1                   поезд                                         бедный
# 2           регулирование  system;using_system.collections.generic;using
# 3                  прибор                                     middleware
# 4  балансировщик_нагрузка                                   утверждаться
# 5               вселенная                                       сбербанк
# 6                 частица                                           neon
# 7               галактика                               средний_зарплата
# 8                 verizon                                            вич
# 9                   лампа                             подробно_разбирать
#
#                  2              3                   4            5   \
# 0  windows_defender             wp                 лвс         боль
# 1         хромосома       capacity       прокси-сервер         кожа
# 2                dd  критичный_баг             openvpn       квеста
# 3               fun          board              shield       гаджет
# 4               hpe          ontap         подключение        realm
# 5            reboot        vserver  цифровой_экономика         ecto
# 6           seconds           esxi                 vps      наушник
# 7    деление_клетка          скайп       unsigned_null    подписчик
# 8                se           zend             колонна  рефакторинг
# 9         коннектор  петербургский        null_default         джон
#
#                       6                     7                         8   \
# 0              std::cout           партнерский                   adwords
# 1                myclass                 forms                    pebble
# 2               packages  среднестатистический                      dart
# 3                  фасад               «только     орган_государственный
# 4  регулярно_обновляться           досконально           ёмкость_батарея
# 5          занятие_спорт               ansible                        pf
# 6     публично_доступный            быстренько                   дискета
# 7    испытание_двигатель              заводить                    fitbit
# 8              generator                   ачх  объектно-ориентированный
# 9              sim-карта                 alexa                        s3
#
#             9            10           11              12             13  \
# 0       печать        users       доклад             php    token_token
# 1      головка     messages       сигнал            else    магнитометр
# 2      laravel        clion    процессор            html        8.8.8.8
# 3       корпус  async/await     подборка  преобразование       intellij
# 4      изделие      angular     инцидент        нативный           rust
# 5        apply        cmake  температура          дерево             xe
# 6  температура     template     гипотеза          string        traffic
# 7      принтер        flask        слайд          символ     вентилятор
# 8     филамент         user      питание           const        получас
# 9      пластик        admin         цвет          chrome  снижение_риск
#
#               14          15                 16                 17  \
# 0         footer     браузер               кндр           гибкость
# 1    «вконтакте»       игрок                 cs            bitcoin
# 2  output_output   сообщение    выпадать_список   main(string_args
# 3         казино      запрос             margin             beyond
# 4         widget    страница  представительство         фреймворок
# 5            req    документ      присоединение                 cc
# 6        pattern   компонент      игнорирование         pvs-studio
# 7    size_t_size      список             ночное        workstation
# 8        updated      модуль        новосибирск           обменять
# 9           20px  библиотека              input  ребёнок_подросток
#
#                        18                     19
# 0                   yahoo                  ipsec
# 1                firewall                     vi
# 2                listview                    sed
# 3  беспилотный_автомобиль                  tuple
# 4         никак_удаваться                  хабов
# 5                  gaming               behavior
# 6               автопилот                 syslog
# 7          учётный_запись                     бп
# 8              отдаваться       обход_блокировка
# 9                     faq  постараться_объяснить

# %% [markdown]
# #### 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)

# %% [markdown]
# Tfidf не улучшил качество работы моделей, а только ухудшил, появились темы, которые ранее не встречались, а аналогов выбранных тем даже нет. Кажется, что слова в темах выбраны рандомно, поэтому не удается выбрать даже одну полноценно хорошую тему. В топ попадает много слов, связанных с программированием(названия функций и тд), возможно, при их удалении картина может измениться, но не очень понятно, как это сделать, если только не убрать все английские слова.

# %% [markdown]
# ### 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
stexts = [' '.join(text) for text in texts]

# %% [markdown]
# Сделаем матрицу слова-документы с помощью TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=25000, min_df=5, max_df=0.3, lowercase=False)
X = vectorizer.fit_transform(stexts)

# %% [markdown]
# Разложим её.

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(20):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 10)

# %% [markdown]
# Модель выдает хорошие результаты (например, тема 25), попробуем изменить параметры

# %%
def my_nmf(stexts, max_features=25000, min_df=0.2, max_df=0.3, lowercase=False):

    vectorizer = TfidfVectorizer(max_features=25000, min_df=5, max_df=0.3, lowercase=False)
    X = vectorizer.fit_transform(stexts)
    
    model = NMF(n_components=30)
    model.fit(X)
    
    return get_nmf_topics(model, 10)

# %%
my_nmf(stexts, max_features=5000, min_df=0.0, max_df=0.3)
# Out:
#          Topic # 01  Topic # 02   Topic # 03     Topic # 04   Topic # 05  \
# 0       программист      скрипт  изображение        windows     смартфон
# 1         сотрудник   настройка     текстура      microsoft      телефон
# 2  программирование       пакет     алгоритм          linux      android
# 3              опыт       папка        точка     обновление        экран
# 4              идея   контейнер        карта             ос  аккумулятор
# 5             книга   установка   координата  visual_studio    мобильный
# 6             жизнь  директория      пиксель      платформа      дисплей
# 7              день      сборка       размер        драйвер        apple
# 8              курс      docker         слой     уязвимость       корпус
# 9            знание         amp     анимация   операционный      ноутбук
#
#    Topic # 06                   Topic # 07   Topic # 08  Topic # 09  \
# 0       рынок                        атака      спутник  javascript
# 1      бизнес                   уязвимость       ракета         css
# 2     продукт                 безопасность       орбита          js
# 3   мобильный                злоумышленник      станция  библиотека
# 4    блокчейн                  вредоносный         марс     angular
# 5      страна                       пароль  космический         vue
# 6      сервис                       защита        земля         api
# 7  российский                       доступ         наса         веб
# 8     крупный  информационный_безопасность      аппарат        node
# 9      деньга                       угроза       космос      модуль
#
#                Topic # 10 Topic # 11   Topic # 12     Topic # 13  \
# 0                   игрок      класс       доклад          робот
# 1                 игровой        new  конференция        ребёнок
# 2                  играть     string       спикер         датчик
# 3                персонаж        int     участник         машина
# 4                      vr        var   рассказать  робототехника
# 5                    враг     public  выступление       движение
# 6                геймплей       else      встреча     автомобиль
# 7                     мир        amp         тема           дрон
# 8  виртуальный_реальность       null  мероприятие      способный
# 9                  миссия       void         java         дронов
#
#            Topic # 14  Topic # 15    Topic # 16    Topic # 17  Topic # 18  \
# 0           процессор       react          мозг        печать   вселенная
# 1              память   компонент        учёный       принтер   галактика
# 2                ядро       props       пациент            3d      звезда
# 3                диск         dom        клетка      материал     энергия
# 4  производительность  компонента  исследование  производство      солнце
# 5               intel      render   заболевание        станок        свет
# 6                 ssd    свойство           ген        деталь    миллиард
# 7           компьютер         jsx       болезнь      печатать  гравитация
# 8          накопитель         div          врач       пластик      теория
# 9          инструкция   состояние       лечение       изделие     частица
#
#    Topic # 19    Topic # 20
# 0         бот          тест
# 1    telegram  тестирование
# 2   сообщение      тестовый
# 3         чат   тестировать
# 4       канал    библиотека
# 5    телеграм        ошибка
# 6         api      сценарий
# 7  мессенджер           tdd
# 8         bot          test
# 9        лига   тестировщик

# %%
my_nmf(stexts, max_features=10000, min_df=0.3, max_df=1)
# Out:
#          Topic # 01  Topic # 02   Topic # 03 Topic # 04   Topic # 05  \
# 0             книга       пакет  изображение    windows     смартфон
# 1       программист   настройка     алгоритм       ядро      телефон
# 2  программирование      скрипт     текстура  процессор        экран
# 3            читать       адрес        точка     память  аккумулятор
# 4        заниматься          ip        карта  microsoft      дисплей
# 5             жизнь       папка   координата      linux      ноутбук
# 6            думать  сертификат       размер       диск       корпус
# 7              часы       домен      пиксель         ос        apple
# 8              идея   установка         слой      intel      батарея
# 9              курс      пароль     анимация    драйвер         цена
#
#    Topic # 06                   Topic # 07   Topic # 08 Topic # 09 Topic # 10  \
# 0   сотрудник                        атака      спутник  мобильный      игрок
# 1      бизнес                   уязвимость       ракета    продукт    игровой
# 2    документ                 безопасность       орбита    android     играть
# 3      деньга                злоумышленник         марс     google   персонаж
# 4    заказчик                  вредоносный  космический    реклама       враг
# 5       рынок                       пароль        земля     сервис         vr
# 6  российский                       защита      станция    контент        мир
# 7     продукт                       доступ         наса     дизайн   геймплей
# 8      страна                       угроза      аппарат        ios     миссия
# 9     крупный  информационный_безопасность       космос  платформа    комната
#
#   Topic # 11   Topic # 12     Topic # 13 Topic # 14   Topic # 15  \
# 0      класс       доклад          робот     сигнал      пациент
# 1        new  конференция        ребёнок    частота       клетка
# 2     string       спикер         датчик      канал  заболевание
# 3        int     участник  робототехника   передача          ген
# 4        var  выступление         машина    антенна         врач
# 5        amp   рассказать       движение      плата      болезнь
# 6       else      встреча           дрон        ток      лечение
# 7     public  мероприятие      способный   диапазон     бактерия
# 8       null         тема         сборка   скорость     организм
# 9       void         java     автомобиль      связь       учёный
#
#       Topic # 16    Topic # 17  Topic # 18  Topic # 19          Topic # 20
# 0           мозг        печать   вселенная         бот                тест
# 1         учёный       принтер   галактика   сообщение        тестирование
# 2   исследование            3d      звезда    telegram            тестовый
# 3       сознание      материал     энергия       канал         тестировать
# 4         нейрон  производство      солнце         чат              ошибка
# 5        область        станок        свет    телеграм          библиотека
# 6       движение        деталь    миллиард         api            сценарий
# 7     активность      печатать  гравитация  мессенджер  производительность
# 8  исследователь       пластик      теория      сервис                test
# 9       животное       изделие     частица         bot              подход

# %%
my_nmf(stexts, max_features=25000, min_df=0.1, max_df=0.6)
# Out:
#          Topic # 01 Topic # 02   Topic # 03  Topic # 04   Topic # 05  \
# 0             книга     запрос  изображение       пакет       камера
# 1       программист   страница     текстура   настройка     смартфон
# 2  программирование    таблица     алгоритм       адрес        видео
# 3              идея       база        точка      скрипт      телефон
# 4              курс     запись         блок          ip        экран
# 5             жизнь     строка        карта       домен  аккумулятор
# 6            думать         бд   координата  сертификат       корпус
# 7            знание     индекс     анимация   установка      дисплей
# 8            понять   документ       размер       папка  регистратор
# 9              опыт      ответ      пиксель      пароль       датчик
#
#    Topic # 06     Topic # 07   Topic # 08 Topic # 09 Topic # 10 Topic # 11  \
# 0   сотрудник          атака      спутник  мобильный      игрок      класс
# 1      бизнес     уязвимость       ракета    android    игровой        new
# 2       рынок   безопасность       орбита     google     играть     string
# 3    документ  злоумышленник      станция    продукт   персонаж        var
# 4  российский    вредоносный         марс    реклама       враг     public
# 5    заказчик         защита  космический        ios         vr       null
# 6      деньга         пароль        земля     сервис   геймплей         id
# 7      страна         доступ         наса    контент        мир      class
# 8     продукт         угроза      аппарат      рынок     миссия    private
# 9     крупный         ботнет       космос     дизайн    комната       name
#
#     Topic # 12     Topic # 13          Topic # 14   Topic # 15     Topic # 16  \
# 0       доклад          робот           процессор      пациент           мозг
# 1  конференция        ребёнок              память       клетка         учёный
# 2       спикер         датчик                диск  заболевание   исследование
# 3     участник  робототехника                ядро          ген       сознание
# 4  выступление         машина  производительность         врач         нейрон
# 5   рассказать       движение               intel      болезнь        область
# 6      встреча           дрон                 ssd      лечение       движение
# 7  мероприятие     автомобиль                  вм     бактерия     активность
# 8         тема      способный          накопитель       учёный       животное
# 9         java         сборка              запись     организм  исследователь
#
#      Topic # 17  Topic # 18  Topic # 19    Topic # 20
# 0        печать   вселенная         бот          тест
# 1       принтер   галактика   сообщение  тестирование
# 2            3d      звезда    telegram      тестовый
# 3      материал     энергия       канал   тестировать
# 4  производство      солнце         чат        ошибка
# 5        станок        свет    телеграм    библиотека
# 6        деталь    миллиард  мессенджер      сценарий
# 7      печатать  гравитация         api          test
# 8       пластик      теория      сервис           баг
# 9       изделие     частица         bot           tdd

# %%
my_nmf(stexts, max_features=25000, min_df=0.3, max_df=0.1)
# Out:
#   Topic # 01 Topic # 02   Topic # 03             Topic # 04   Topic # 05  \
# 0  сотрудник     запрос  изображение                   диск     смартфон
# 1    продукт     скрипт     текстура                     вм      телефон
# 2     бизнес   страница        карта     виртуальный_машина  аккумулятор
# 3     деньга      пакет        точка            виртуальный        экран
# 4       день      адрес     алгоритм                 запись      дисплей
# 5       опыт  настройка   координата                  бэкап       корпус
# 6   заказчик     строка      пиксель  резервный_копирование      ноутбук
# 7   менеджер     список     анимация                   база      батарея
# 8      жизнь     сервис         слой         восстановление        apple
# 9     понять    таблица       размер              хранилище       гаджет
#
#   Topic # 06     Topic # 07   Topic # 08  Topic # 09 Topic # 10 Topic # 11  \
# 0  мобильный          атака      спутник       react      игрок      класс
# 1    android     уязвимость       ракета  javascript    игровой        new
# 2    продукт   безопасность       орбита   компонент     играть     string
# 3     google  злоумышленник      станция         css   персонаж        var
# 4    реклама         пароль         марс          js       враг     public
# 5        ios    вредоносный  космический     angular         vr       null
# 6     дизайн         защита        земля  библиотека        мир         id
# 7    контент         доступ         наса     браузер   геймплей      class
# 8  платформа     шифрование      аппарат         dom     миссия    private
# 9     сервис         угроза       космос        html    комната       name
#
#     Topic # 12     Topic # 13          Topic # 14    Topic # 15  \
# 0       доклад          робот           процессор          мозг
# 1  конференция        ребёнок              память        учёный
# 2       спикер         датчик                ядро       пациент
# 3     участник         машина               intel        клетка
# 4  выступление  робототехника  производительность  исследование
# 5   рассказать       движение              модуль   заболевание
# 6      встреча           дрон             регистр           ген
# 7  мероприятие     автомобиль          инструкция       болезнь
# 8         тема         сборка         архитектура          врач
# 9        слайд      способный               поток       лечение
#
#                 Topic # 16    Topic # 17  Topic # 18  Topic # 19  \
# 0                       ия        печать   вселенная         бот
# 1                нейросеть       принтер   галактика   сообщение
# 2  искусственный_интеллект            3d      звезда    telegram
# 3                 обучение      материал     энергия       канал
# 4                 deepmind  производство      солнце         чат
# 5                   google        станок        свет    телеграм
# 6        машинный_обучение        деталь    миллиард  мессенджер
# 7                нейронный      печатать  гравитация         api
# 8                    агент       пластик      теория      сервис
# 9                   машина       изделие     частица         bot
#
#            Topic # 20
# 0                тест
# 1        тестирование
# 2            тестовый
# 3         тестировать
# 4          библиотека
# 5              ошибка
# 6                test
# 7            сценарий
# 8                 tdd
# 9  производительность

# %%
my_nmf(stexts, max_features=25000, min_df=0.0, max_df=0.3)
# Out:
#          Topic # 01  Topic # 02   Topic # 03 Topic # 04   Topic # 05  \
# 0       программист      скрипт  изображение  мобильный       камера
# 1             книга       пакет     текстура    android     смартфон
# 2  программирование   настройка     алгоритм     google        видео
# 3              идея       папка        точка    продукт      телефон
# 4              курс         php        карта        ios        экран
# 5              опыт   установка   координата    реклама       корпус
# 6             жизнь      модуль      пиксель     дизайн  аккумулятор
# 7              день  директория       размер  платформа      дисплей
# 8            знание      сборка         слой      рынок  регистратор
# 9            думать   контейнер     анимация    контент       датчик
#
#    Topic # 06  Topic # 07   Topic # 08  Topic # 09 Topic # 10 Topic # 11  \
# 0      бизнес   сообщение      спутник       react      игрок      класс
# 1   сотрудник       домен       ракета  javascript    игровой        new
# 2       рынок       адрес       орбита   компонент     играть     string
# 3    блокчейн      сервис      станция         css   персонаж        int
# 4      страна      письмо         марс          js       враг        var
# 5      услуга  сертификат  космический     angular         vr     public
# 6  российский          ip        земля     браузер   геймплей        amp
# 7      деньга      трафик         наса  библиотека        мир       else
# 8     крупный   провайдер      аппарат         dom     миссия       null
# 9    документ       канал       космос        html    комната       void
#
#     Topic # 12               Topic # 13          Topic # 14   Topic # 15  \
# 0       доклад                       ия           процессор      пациент
# 1  конференция                нейросеть              память       клетка
# 2       спикер  искусственный_интеллект                ядро  заболевание
# 3     участник                 обучение               intel          ген
# 4  выступление                 deepmind  производительность         врач
# 5   рассказать                   google             регистр      болезнь
# 6      встреча        машинный_обучение          инструкция      лечение
# 7  мероприятие                нейронный           компьютер     бактерия
# 8         тема               автомобиль              модуль     организм
# 9         java                компьютер                 чип       учёный
#
#       Topic # 16    Topic # 17  Topic # 18  Topic # 19     Topic # 20
# 0           мозг        печать   вселенная         бот          атака
# 1         учёный       принтер   галактика    telegram     уязвимость
# 2   исследование            3d      звезда   сообщение   безопасность
# 3       сознание      материал     энергия         чат  злоумышленник
# 4         нейрон  производство      солнце       канал         пароль
# 5        область        станок        свет    телеграм    вредоносный
# 6       движение        деталь    миллиард         api         защита
# 7     активность      печатать  гравитация  мессенджер         доступ
# 8  исследователь       пластик      теория         bot         ботнет
# 9       животное       изделие     частица        лига         угроза

# %% [markdown]
# Кажется, что вне зависимости от значения пар-ор модели строят отличные темы, лично мне больше всего понравились при max_features=5000, min_df=0.0, max_df=0.3

# %% [markdown]
# ### 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.

# %%
t1 = my_nmf(stexts, max_features=5000, min_df=0.0, max_df=0.3)

# %%
t1 = t1[['Topic # 08', 'Topic # 14', 'Topic # 15']]

# %%
t2 = table1[[1, 10, 19]]

# %%
pd.concat([t1, t2], axis=1)
# Out:
#     Topic # 08  Topic # 14   Topic # 15         1                10  \
# 0      спутник       товар      пациент  операция           студент
# 1       ракета      скидка       клетка      глаз              курс
# 2       орбита        цена  заболевание     лазер  программирование
# 3      станция     магазин          ген        тз           ребёнок
# 4         марс  покупатель         врач    зрение            лекция
# 5  космический     покупка      болезнь     линза          обучение
# 6        земля  распродажа      лечение      flex       программист
# 7         наса     продажа     бактерия  роговица   образовательный
# 8      аппарат    продавец     организм    хирург         компьютер
# 9       космос       акция          днк   пациент            знание
#
#             19
# 0      пациент
# 1         врач
# 2      лечение
# 3      болезнь
# 4  заболевание
# 5     бактерия
# 6     медицина
# 7     организм
# 8          3cx
# 9      больной

# %% [markdown]
# 1) Не смотря на то, что LDA выбрал досточно много неплохо характеризующих слов для тем, в списке все равно попал шум-мусор (3cx, тз, flex)
# В NMF же такого не наблюдается.

# %% [markdown]
# 2) В NMF слова четко специфицированы под тему, даже сложно выбрать 3 лучших, тогда как, например, в 2 теме LDA, слова вроде как по теме, а вроде как бы и не очень.

# %% [markdown]
# 3) Всякие термины связанные с программированием NMF объединил в одну значимую тему, а LDA вставлял подобные слова в соверщенно разные темы.
